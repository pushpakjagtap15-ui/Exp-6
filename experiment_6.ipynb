# %% [markdown]
# <a href="https://colab.research.google.com/github/pushpakjagtap15-ui/Exp-6/blob/main/experiment_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#EXPERIMENT-6
#Name-Pushpak.J
#PRN-25070123148
#Batch-A1
#Dept-ENTC

#check whether number is positive or negative
num=int(input("enter a number"))
if num>0:
    print("positive number")
else :
    print("negative number")
# Out:
# enter a number1
# positive number

# %%
num=int(input("enter a number"))
if num>0:
    print("positive number")

elif num==0:
        print("zero")

else:
            print("negative number")
# Out:
# enter a number0
# zero

# %%
#even odd
num=int(input("enter a number"))
if num%2==0:
    print("even number")
else:
    print("odd number")
# Out:
# enter a number0
# even number

# %%
#largest number


num1=int(input("enter a number1 "))
num2=int(input("enter a number2 "))

if num1>num2:
    print(num1 ,"is largest")
else:
        print(num2 , " is largest")
# Out:
# enter a number1 1
# enter a number2 3
# 3  is largest

# %%
num1=int(input("enter a number1 "))
num2=int(input("enter a number2 "))
num3=int(input("enter a number3 "))

if num1>num2 and num1>num3:
    print(num1,"is greater")

elif num2>num1 and num2>num3:
    print(num2,"is greater")



else:
  num3>num1 and num3>2
  print(num3, "is greater")
# Out:
# enter a number1 99
# enter a number2 908
# enter a number3 999
# 999 is greater
